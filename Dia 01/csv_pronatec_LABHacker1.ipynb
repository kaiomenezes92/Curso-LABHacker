# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Curso LABHacker/Dados/PDA_UNIDADES_RF_EPCT_CSV.csv', sep=';', encoding='cp1252')

# %%
df.head()
# Out:
#    CODIGO_UNIDADE  ... NOME_MICRORREGIAO_UNIDADE
# 0            2879  ...              Porto Seguro
# 1            2948  ...                Itapetinga
# 2           14328  ...            Sena Madureira
# 3           14547  ...                 Arapiraca
# 4           32010  ...     São Miguel dos Campos
#
# [5 rows x 8 columns]

# %%
df['NOME_REGIAO_UNIDADE'].value_counts()
# Out:
# Nordeste        202
# Sudeste         163
# Sul             116
# Norte            70
# Centro-Oeste     67
# Name: NOME_REGIAO_UNIDADE, dtype: int64

# %%
df['SIGLA_UF_UNIDADE'].value_counts()
# Out:
# MG    67
# RS    45
# RJ    39
# SC    36
# SP    35
# PR    35
# BA    34
# CE    27
# MA    27
# GO    26
# PE    23
# PI    23
# RN    23
# ES    22
# PB    21
# PA    20
# MT    19
# AL    16
# AM    15
# MS    11
# TO    11
# DF    11
# RO     8
# SE     8
# RR     6
# AC     6
# AP     4
# Name: SIGLA_UF_UNIDADE, dtype: int64

# %%
# %matplotlib inline

df['SIGLA_UF_UNIDADE'].value_counts().plot.bar()
